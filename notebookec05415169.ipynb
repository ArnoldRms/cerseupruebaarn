# %% [markdown]
# <a href="https://www.kaggle.com/code/arnoldramos/exam2-1?scriptVersionId=118532543" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/kaggle/input/disney/disney_plus_titles - disney_plus_titles.csv')
df
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
list(df.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df[df['release_year']<2000]
# Out:
#      show_id     type                      title  \
# 1         s2    Movie     Ernest Saves Christmas
# 43       s44    Movie         Jingle All The Way
# 56       s57    Movie         Rookie of the Year
# 57       s58    Movie                 Thumbelina
# 89       s90  TV Show           Rolie Polie Olie
# ...      ...      ...                        ...
# 1434   s1435  TV Show                  Smart Guy
# 1435   s1436    Movie   The Cat from Outer Space
# 1436   s1437    Movie  The Great Mouse Detective
# 1437   s1438    Movie     The Sword in the Stone
# 1438   s1439    Movie            Those Calloways
#
#                                       director  \
# 1                                  John Cherry
# 43                                Brian Levant
# 56                                Daniel Stern
# 57                     Don Bluth, Gary Goldman
# 89                                         NaN
# ...                                        ...
# ...

# %%
df['country'].fillna('Sin referencia de país', inplace=True)
df
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
#df['country']
list(df['country'].value_counts())
x_val=df.release_year.unique()
x_val
y_val=list(df['release_year'].value_counts())
y_val
plt.bar(x_val,y_val)
plt.title('barras teniendo en cuenta como valores a los países')
ax=plt.subplot()
#ax.set_xticks(x_val)
#ax.set_xticklabels(x_val)
ax.set_xlabel('Pais')
ax.set_ylabel('Cuenta')
# Out:
# Text(0, 0.5, 'Cuenta')

# %%
#ordenar grafica segun año
df_p = df.sort_values('release_year')
x_values = df_p.release_year.unique()
y_values = list(df_p['release_year'].value_counts())
plt.plot(x_values, y_values, marker='o', linestyle='--')
plt.show()
plt.savefig("Grafica-descarga-examen.png")

# %%
x_values = ["Movie", "TV Show"]
y_values =df['type'].value_counts()
plt.pie(y_values, labels=x_values)
plt.show()

# %%
x_values = ["Movie"]
y_values =df['type'][df['type']=="Movie"].value_counts()
plt.pie(y_values, labels=x_values)
plt.show()
